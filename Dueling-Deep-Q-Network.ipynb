# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):        
        inputs = layers.Input(shape=(observation_shape))
        h1 = layers.Dense(20, activation='relu')(inputs)
        h1 = layers.Dense(10, activation='relu')(h1)
        V = layers.Dense(1)(h1)
        
        h2 = layers.Dense(20, activation='relu')(inputs)
        h2 = layers.Dense(10, activation='relu')(h2)
        advantage = layers.Dense(action_shape)(h2)
        mean_adv = layers.Lambda(lambda x: tf.keras.backend.mean(x, axis=1))(advantage)
        
        outputs = layers.Add()([V, layers.Subtract()([advantage, mean_adv])])
    
        self.model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
        
        self.model.compile(
            loss=tf.keras.losses.Huber(), 
            optimizer=tf.optimizers.Adam(learning_rate=lr), 
            metrics=['accuracy']
        )
        
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.train_on_batch(batch_x, batch_y)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(mode, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = [e.observation for e in minibatch]
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(np.array(batch_curr_observations))
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = [e.new_observation for e in minibatch]
    # batch_new_qualities shape: [batch size, action size]
    batch_new_qualities = model.forward(np.array(batch_new_observations))
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_new_qualities[id]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*max(new_qualities)
        # desired_qualities shape: [action size]
        desired_qualities = curr_qualities
        desired_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(desired_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, minibatch)
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  12, experience size:  1012
# round:   2, reward:  24, experience size:  1036
# round:   3, reward:   9, experience size:  1045
# round:   4, reward:  28, experience size:  1073
# round:   5, reward:  12, experience size:  1085
# round:   6, reward:  34, experience size:  1119
# round:   7, reward:  16, experience size:  1135
# round:   8, reward:  17, experience size:  1152
# round:   9, reward:  28, experience size:  1180
# round:  10, reward:  31, experience size:  1211
# round:  11, reward:  63, experience size:  1274
# round:  12, reward:  13, experience size:  1287
# round:  13, reward:  17, experience size:  1304
# round:  14, reward:  58, experience size:  1362
# round:  15, reward:  11, experience size:  1373
# round:  16, reward:  15, experience size:  1388
# round:  17, reward:  32, experience size:  1420
# round:  18, reward:  42, experience size:  1462
# round:  19, reward:  14, experience size:  1476
# round:  20, reward:  29, experience size:  1505
# round:  21, reward:  15, experience size:  1520
# round:  22, reward:  10, experience size:  1530
# round:  23, reward:  20, experience size:  1550
# round:  24, reward:  19, experience size:  1569
# round:  25, reward:  18, experience size:  1587
# round:  26, reward:  27, experience size:  1614
# round:  27, reward:  11, experience size:  1625
# round:  28, reward:  21, experience size:  1646
# round:  29, reward:  33, experience size:  1679
# round:  30, reward:  24, experience size:  1703
# round:  31, reward:  15, experience size:  1718
# round:  32, reward:  15, experience size:  1733
# round:  33, reward:  33, experience size:  1766
# round:  34, reward:  14, experience size:  1780
# round:  35, reward:  37, experience size:  1817
# round:  36, reward:  22, experience size:  1839
# round:  37, reward:  17, experience size:  1856
# round:  38, reward:  30, experience size:  1886
# round:  39, reward:  32, experience size:  1918
# round:  40, reward:  10, experience size:  1928
# round:  41, reward:  11, experience size:  1939
# round:  42, reward:  15, experience size:  1954
# round:  43, reward:  18, experience size:  1972
# round:  44, reward:  11, experience size:  1983
# round:  45, reward:  37, experience size:  2020
# round:  46, reward:  27, experience size:  2047
# round:  47, reward:  11, experience size:  2058
# round:  48, reward:  11, experience size:  2069
# round:  49, reward:  12, experience size:  2081
# round:  50, reward:  13, experience size:  2094
# round:  51, reward:  18, experience size:  2112
# round:  52, reward:  21, experience size:  2133
# round:  53, reward:  11, experience size:  2144
# round:  54, reward:   8, experience size:  2152
# round:  55, reward:  12, experience size:  2164
# round:  56, reward:  10, experience size:  2174
# round:  57, reward:  22, experience size:  2196
# round:  58, reward:  17, experience size:  2213
# round:  59, reward:   9, experience size:  2222
# round:  60, reward:  15, experience size:  2237
# round:  61, reward:  13, experience size:  2250
# round:  62, reward:  10, experience size:  2260
# round:  63, reward:  15, experience size:  2275
# round:  64, reward:  30, experience size:  2305
# round:  65, reward:  17, experience size:  2322
# round:  66, reward:  10, experience size:  2332
# round:  67, reward:  11, experience size:  2343
# round:  68, reward:  20, experience size:  2363
# round:  69, reward:  16, experience size:  2379
# round:  70, reward:  17, experience size:  2396
# round:  71, reward:  12, experience size:  2408
# round:  72, reward:  18, experience size:  2426
# round:  73, reward:  10, experience size:  2436
# round:  74, reward:  19, experience size:  2455
# round:  75, reward:  10, experience size:  2465
# round:  76, reward:  13, experience size:  2478
# round:  77, reward:  12, experience size:  2490
# round:  78, reward:  14, experience size:  2504
# round:  79, reward:  10, experience size:  2514
# round:  80, reward:  22, experience size:  2536
# round:  81, reward:  27, experience size:  2563
# round:  82, reward:  10, experience size:  2573
# round:  83, reward:  10, experience size:  2583
# round:  84, reward:  14, experience size:  2597
# round:  85, reward:   9, experience size:  2606
# round:  86, reward:  10, experience size:  2616
# round:  87, reward:  12, experience size:  2628
# round:  88, reward:  15, experience size:  2643
# round:  89, reward:  15, experience size:  2658
# round:  90, reward:  18, experience size:  2676
# round:  91, reward:  19, experience size:  2695
# round:  92, reward:  27, experience size:  2722
# round:  93, reward:  40, experience size:  2762
# round:  94, reward:  17, experience size:  2779
# round:  95, reward:  22, experience size:  2801
# round:  96, reward:  33, experience size:  2834
# round:  97, reward:  26, experience size:  2860
# round:  98, reward:  51, experience size:  2911
# round:  99, reward:  20, experience size:  2931
# round: 100, reward:  23, experience size:  2954
# round: 101, reward:  19, experience size:  2973
# round: 102, reward:  35, experience size:  3008
# round: 103, reward:  50, experience size:  3058
# round: 104, reward:  28, experience size:  3086
# round: 105, reward:  40, experience size:  3126
# round: 106, reward:  42, experience size:  3168
# round: 107, reward:  21, experience size:  3189
# round: 108, reward:  21, experience size:  3210
# round: 109, reward:  30, experience size:  3240
# round: 110, reward:  42, experience size:  3282
# round: 111, reward:  29, experience size:  3311
# round: 112, reward:  73, experience size:  3384
# round: 113, reward:  73, experience size:  3457
# round: 114, reward:  27, experience size:  3484
# round: 115, reward:  38, experience size:  3522
# round: 116, reward:  34, experience size:  3556
# round: 117, reward:  31, experience size:  3587
# round: 118, reward:  34, experience size:  3621
# round: 119, reward:  72, experience size:  3693
# round: 120, reward:  43, experience size:  3736
# round: 121, reward:  46, experience size:  3782
# round: 122, reward:  41, experience size:  3823
# round: 123, reward:  32, experience size:  3855
# round: 124, reward:  22, experience size:  3877
# round: 125, reward:  82, experience size:  3959
# round: 126, reward: 170, experience size:  4129
# round: 127, reward:  63, experience size:  4192
# round: 128, reward:  40, experience size:  4232
# round: 129, reward:  53, experience size:  4285
# round: 130, reward:  38, experience size:  4323
# round: 131, reward:  29, experience size:  4352
# round: 132, reward:  36, experience size:  4388
# round: 133, reward: 181, experience size:  4569
# round: 134, reward:  66, experience size:  4635
# round: 135, reward: 109, experience size:  4744
# round: 136, reward:  73, experience size:  4817
# round: 137, reward:  43, experience size:  4860
# round: 138, reward:  63, experience size:  4923
# round: 139, reward:  61, experience size:  4984
# round: 140, reward:  69, experience size:  5000
# round: 141, reward:  13, experience size:  5000
# round: 142, reward:  34, experience size:  5000
# round: 143, reward:  45, experience size:  5000
# round: 144, reward: 128, experience size:  5000
# round: 145, reward:  38, experience size:  5000
# round: 146, reward:  33, experience size:  5000
# round: 147, reward:  56, experience size:  5000
# round: 148, reward: 105, experience size:  5000
# round: 149, reward:  76, experience size:  5000
# round: 150, reward: 101, experience size:  5000
# round: 151, reward: 219, experience size:  5000
# round: 152, reward:  70, experience size:  5000
# round: 153, reward:  94, experience size:  5000
# round: 154, reward: 112, experience size:  5000
# round: 155, reward: 149, experience size:  5000
# round: 156, reward: 111, experience size:  5000
# round: 157, reward: 136, experience size:  5000
# round: 158, reward:  71, experience size:  5000
# round: 159, reward: 101, experience size:  5000
# round: 160, reward: 141, experience size:  5000
# round: 161, reward: 149, experience size:  5000
# round: 162, reward: 113, experience size:  5000
# round: 163, reward: 148, experience size:  5000
# round: 164, reward: 128, experience size:  5000
# round: 165, reward: 121, experience size:  5000
# round: 166, reward: 173, experience size:  5000
# round: 167, reward: 216, experience size:  5000
# round: 168, reward: 227, experience size:  5000
# round: 169, reward: 124, experience size:  5000
# round: 170, reward: 230, experience size:  5000
# round: 171, reward: 377, experience size:  5000
# round: 172, reward: 204, experience size:  5000
# round: 173, reward: 182, experience size:  5000
# round: 174, reward: 167, experience size:  5000
# round: 175, reward: 189, experience size:  5000
# round: 176, reward: 208, experience size:  5000
# round: 177, reward: 137, experience size:  5000
# round: 178, reward: 152, experience size:  5000
# round: 179, reward: 157, experience size:  5000
# round: 180, reward: 177, experience size:  5000
# round: 181, reward: 242, experience size:  5000
# round: 182, reward: 234, experience size:  5000
# round: 183, reward: 177, experience size:  5000
# round: 184, reward: 187, experience size:  5000
# round: 185, reward: 282, experience size:  5000
# round: 186, reward: 171, experience size:  5000
# round: 187, reward: 359, experience size:  5000
# round: 188, reward: 192, experience size:  5000
# round: 189, reward: 192, experience size:  5000
# round: 190, reward: 198, experience size:  5000
# round: 191, reward: 163, experience size:  5000
# round: 192, reward: 301, experience size:  5000
# round: 193, reward: 242, experience size:  5000
# round: 194, reward: 158, experience size:  5000
# round: 195, reward: 215, experience size:  5000
# round: 196, reward: 214, experience size:  5000
# round: 197, reward: 197, experience size:  5000
# round: 198, reward: 223, experience size:  5000
# round: 199, reward: 160, experience size:  5000
# round: 200, reward: 173, experience size:  5000
# CPU times: user 9min 16s, sys: 15.4 s, total: 9min 31s
# Wall time: 8min 58s

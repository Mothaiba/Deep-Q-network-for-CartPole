# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
STEPS_PER_TARGET_MODEL_COPY = 50
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):
        inputs = layers.Input(shape=(observation_shape))
        h1 = layers.Dense(20, activation='relu')(inputs)
        h1 = layers.Dense(10, activation='relu')(h1)
        V = layers.Dense(1)(h1)
        
        h2 = layers.Dense(20, activation='relu')(inputs)
        h2 = layers.Dense(10, activation='relu')(h2)
        advantage = layers.Dense(action_shape)(h2)
        mean_adv = layers.Lambda(lambda x: tf.keras.backend.mean(x, axis=1))(advantage)
        
        outputs = layers.Add()([V, layers.Subtract()([advantage, mean_adv])])
    
        self.model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
        
        self.model.compile(
            loss=tf.keras.losses.Huber(), 
            optimizer=tf.optimizers.Adam(learning_rate=lr), 
            metrics=['accuracy']
        )
    
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.train_on_batch(batch_x, batch_y)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(model, target_model, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = [e.observation for e in minibatch]
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(np.array(batch_curr_observations))
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = [e.new_observation for e in minibatch]
    # batch_new_qualities shape: [batch size, action size]
    batch_new_qualities = target_model.forward(np.array(batch_new_observations))
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_new_qualities[id]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*max(new_qualities)
        # desired_qualities shape: [action size]
        desired_qualities = curr_qualities
        desired_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(desired_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model.set_weights(model.get_weights())

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, target_model, minibatch)
        
        # copy the main model to the target_model
        if train_step_count >= STEPS_PER_TARGET_MODEL_COPY:
            target_model.set_weights(model.get_weights())
            train_step_count = 0
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  25, experience size:  1025
# round:   2, reward:  21, experience size:  1046
# round:   3, reward:  29, experience size:  1075
# round:   4, reward:  13, experience size:  1088
# round:   5, reward:  21, experience size:  1109
# round:   6, reward:  11, experience size:  1120
# round:   7, reward:  28, experience size:  1148
# round:   8, reward:  16, experience size:  1164
# round:   9, reward:  21, experience size:  1185
# round:  10, reward:  70, experience size:  1255
# round:  11, reward:  12, experience size:  1267
# round:  12, reward:  18, experience size:  1285
# round:  13, reward:  18, experience size:  1303
# round:  14, reward:  43, experience size:  1346
# round:  15, reward:  17, experience size:  1363
# round:  16, reward:  29, experience size:  1392
# round:  17, reward:   9, experience size:  1401
# round:  18, reward:  27, experience size:  1428
# round:  19, reward:  19, experience size:  1447
# round:  20, reward:  28, experience size:  1475
# round:  21, reward:  44, experience size:  1519
# round:  22, reward:  23, experience size:  1542
# round:  23, reward:  25, experience size:  1567
# round:  24, reward:  20, experience size:  1587
# round:  25, reward:  37, experience size:  1624
# round:  26, reward:  18, experience size:  1642
# round:  27, reward:  14, experience size:  1656
# round:  28, reward:  24, experience size:  1680
# round:  29, reward:  27, experience size:  1707
# round:  30, reward:  14, experience size:  1721
# round:  31, reward:  24, experience size:  1745
# round:  32, reward:  20, experience size:  1765
# round:  33, reward:  13, experience size:  1778
# round:  34, reward:  34, experience size:  1812
# round:  35, reward:  25, experience size:  1837
# round:  36, reward:  14, experience size:  1851
# round:  37, reward:  10, experience size:  1861
# round:  38, reward:  10, experience size:  1871
# round:  39, reward:   9, experience size:  1880
# round:  40, reward:  13, experience size:  1893
# round:  41, reward:  22, experience size:  1915
# round:  42, reward:  10, experience size:  1925
# round:  43, reward:  12, experience size:  1937
# round:  44, reward:  20, experience size:  1957
# round:  45, reward:  13, experience size:  1970
# round:  46, reward:  13, experience size:  1983
# round:  47, reward:  11, experience size:  1994
# round:  48, reward:  20, experience size:  2014
# round:  49, reward:  12, experience size:  2026
# round:  50, reward:  15, experience size:  2041
# round:  51, reward:  21, experience size:  2062
# round:  52, reward:   9, experience size:  2071
# round:  53, reward:  10, experience size:  2081
# round:  54, reward:  12, experience size:  2093
# round:  55, reward:  15, experience size:  2108
# round:  56, reward:  12, experience size:  2120
# round:  57, reward:  12, experience size:  2132
# round:  58, reward:  13, experience size:  2145
# round:  59, reward:  26, experience size:  2171
# round:  60, reward:  19, experience size:  2190
# round:  61, reward:  13, experience size:  2203
# round:  62, reward:  13, experience size:  2216
# round:  63, reward:  13, experience size:  2229
# round:  64, reward:  30, experience size:  2259
# round:  65, reward:  14, experience size:  2273
# round:  66, reward:  24, experience size:  2297
# round:  67, reward:  15, experience size:  2312
# round:  68, reward:  15, experience size:  2327
# round:  69, reward:  15, experience size:  2342
# round:  70, reward:  35, experience size:  2377
# round:  71, reward:  15, experience size:  2392
# round:  72, reward:  15, experience size:  2407
# round:  73, reward:  10, experience size:  2417
# round:  74, reward:  12, experience size:  2429
# round:  75, reward:  17, experience size:  2446
# round:  76, reward:  14, experience size:  2460
# round:  77, reward:  14, experience size:  2474
# round:  78, reward:  13, experience size:  2487
# round:  79, reward:  19, experience size:  2506
# round:  80, reward:  13, experience size:  2519
# round:  81, reward:  11, experience size:  2530
# round:  82, reward:  16, experience size:  2546
# round:  83, reward:  13, experience size:  2559
# round:  84, reward:  16, experience size:  2575
# round:  85, reward:  15, experience size:  2590
# round:  86, reward:   9, experience size:  2599
# round:  87, reward:   8, experience size:  2607
# round:  88, reward:  18, experience size:  2625
# round:  89, reward:  10, experience size:  2635
# round:  90, reward:  13, experience size:  2648
# round:  91, reward:  20, experience size:  2668
# round:  92, reward:  13, experience size:  2681
# round:  93, reward:   9, experience size:  2690
# round:  94, reward:  13, experience size:  2703
# round:  95, reward:  11, experience size:  2714
# round:  96, reward:  15, experience size:  2729
# round:  97, reward:  10, experience size:  2739
# round:  98, reward:  10, experience size:  2749
# round:  99, reward:  14, experience size:  2763
# round: 100, reward:  12, experience size:  2775
# round: 101, reward:  10, experience size:  2785
# round: 102, reward:  10, experience size:  2795
# round: 103, reward:   9, experience size:  2804
# round: 104, reward:  10, experience size:  2814
# round: 105, reward:  11, experience size:  2825
# round: 106, reward:  11, experience size:  2836
# round: 107, reward:  15, experience size:  2851
# round: 108, reward:  12, experience size:  2863
# round: 109, reward:  13, experience size:  2876
# round: 110, reward:  12, experience size:  2888
# round: 111, reward:   9, experience size:  2897
# round: 112, reward:  12, experience size:  2909
# round: 113, reward:  12, experience size:  2921
# round: 114, reward:  10, experience size:  2931
# round: 115, reward:  17, experience size:  2948
# round: 116, reward:  25, experience size:  2973
# round: 117, reward:   9, experience size:  2982
# round: 118, reward:  10, experience size:  2992
# round: 119, reward:  13, experience size:  3005
# round: 120, reward:  17, experience size:  3022
# round: 121, reward:  14, experience size:  3036
# round: 122, reward:   8, experience size:  3044
# round: 123, reward:  13, experience size:  3057
# round: 124, reward:  11, experience size:  3068
# round: 125, reward:  13, experience size:  3081
# round: 126, reward:  20, experience size:  3101
# round: 127, reward:  15, experience size:  3116
# round: 128, reward:   9, experience size:  3125
# round: 129, reward:  14, experience size:  3139
# round: 130, reward:  25, experience size:  3164
# round: 131, reward:  32, experience size:  3196
# round: 132, reward:  65, experience size:  3261
# round: 133, reward:  51, experience size:  3312
# round: 134, reward:  50, experience size:  3362
# round: 135, reward:  46, experience size:  3408
# round: 136, reward:  39, experience size:  3447
# round: 137, reward:  36, experience size:  3483
# round: 138, reward:  19, experience size:  3502
# round: 139, reward:  54, experience size:  3556
# round: 140, reward:  40, experience size:  3596
# round: 141, reward:  56, experience size:  3652
# round: 142, reward:  34, experience size:  3686
# round: 143, reward:  19, experience size:  3705
# round: 144, reward:  32, experience size:  3737
# round: 145, reward:  59, experience size:  3796
# round: 146, reward:  42, experience size:  3838
# round: 147, reward:  61, experience size:  3899
# round: 148, reward:  26, experience size:  3925
# round: 149, reward:  29, experience size:  3954
# round: 150, reward:  88, experience size:  4042
# round: 151, reward:  73, experience size:  4115
# round: 152, reward:  34, experience size:  4149
# round: 153, reward:  47, experience size:  4196
# round: 154, reward:  38, experience size:  4234
# round: 155, reward: 102, experience size:  4336
# round: 156, reward:  21, experience size:  4357
# round: 157, reward:  65, experience size:  4422
# round: 158, reward:  25, experience size:  4447
# round: 159, reward:  22, experience size:  4469
# round: 160, reward:  41, experience size:  4510
# round: 161, reward:  86, experience size:  4596
# round: 162, reward:  57, experience size:  4653
# round: 163, reward:  46, experience size:  4699
# round: 164, reward:  26, experience size:  4725
# round: 165, reward:  25, experience size:  4750
# round: 166, reward:  29, experience size:  4779
# round: 167, reward:  35, experience size:  4814
# round: 168, reward:  38, experience size:  4852
# round: 169, reward:  28, experience size:  4880
# round: 170, reward:  33, experience size:  4913
# round: 171, reward:  26, experience size:  4939
# round: 172, reward:  23, experience size:  4962
# round: 173, reward:  24, experience size:  4986
# round: 174, reward:  31, experience size:  5000
# round: 175, reward:  38, experience size:  5000
# round: 176, reward:  77, experience size:  5000
# round: 177, reward:  72, experience size:  5000
# round: 178, reward:  50, experience size:  5000
# round: 179, reward: 102, experience size:  5000
# round: 180, reward: 126, experience size:  5000
# round: 181, reward:  91, experience size:  5000
# round: 182, reward: 113, experience size:  5000
# round: 183, reward:  88, experience size:  5000
# round: 184, reward:  87, experience size:  5000
# round: 185, reward: 102, experience size:  5000
# round: 186, reward:  92, experience size:  5000
# round: 187, reward: 205, experience size:  5000
# round: 188, reward: 100, experience size:  5000
# round: 189, reward: 217, experience size:  5000
# round: 190, reward: 195, experience size:  5000
# round: 191, reward: 127, experience size:  5000
# round: 192, reward: 108, experience size:  5000
# round: 193, reward:  75, experience size:  5000
# round: 194, reward: 270, experience size:  5000
# round: 195, reward: 356, experience size:  5000
# round: 196, reward: 165, experience size:  5000
# round: 197, reward: 164, experience size:  5000
# round: 198, reward: 124, experience size:  5000
# round: 199, reward: 358, experience size:  5000
# round: 200, reward: 211, experience size:  5000
# CPU times: user 5min 4s, sys: 8.84 s, total: 5min 13s
# Wall time: 4min 54s

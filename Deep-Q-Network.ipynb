# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
STEPS_PER_TARGET_MODEL_COPY = 50
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):
        self.model = tf.keras.Sequential([
            tf.keras.layers.Dense(20, activation='relu', input_shape=observation_shape),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(action_shape),
        ])
        
        self.model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.optimizers.Adam(learning_rate=lr), metrics=['accuracy'])
    
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.train_on_batch(batch_x, batch_y)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(mode, target_model, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = [e.observation for e in minibatch]
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(np.array(batch_curr_observations))
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = [e.new_observation for e in minibatch]
    # batch_new_qualities shape: [batch size, action size]
    batch_new_qualities = target_model.forward(np.array(batch_new_observations))
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_new_qualities[id]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*max(new_qualities)
        # desired_qualities shape: [action size]
        desired_qualities = curr_qualities
        desired_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(desired_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model.set_weights(model.get_weights())

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, target_model, minibatch)
        
        # copy the main model to the target_model
        if train_step_count >= STEPS_PER_TARGET_MODEL_COPY:
            target_model.set_weights(model.get_weights())
            train_step_count = 0
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  19, experience size:  1019
# round:   2, reward:  36, experience size:  1055
# round:   3, reward:  34, experience size:  1089
# round:   4, reward:  17, experience size:  1106
# round:   5, reward:  26, experience size:  1132
# round:   6, reward:  17, experience size:  1149
# round:   7, reward:  18, experience size:  1167
# round:   8, reward:  24, experience size:  1191
# round:   9, reward:  15, experience size:  1206
# round:  10, reward:  18, experience size:  1224
# round:  11, reward:  39, experience size:  1263
# round:  12, reward:  13, experience size:  1276
# round:  13, reward:  29, experience size:  1305
# round:  14, reward:  26, experience size:  1331
# round:  15, reward:  43, experience size:  1374
# round:  16, reward:  21, experience size:  1395
# round:  17, reward:  27, experience size:  1422
# round:  18, reward:  24, experience size:  1446
# round:  19, reward:  22, experience size:  1468
# round:  20, reward:  13, experience size:  1481
# round:  21, reward:  32, experience size:  1513
# round:  22, reward:  24, experience size:  1537
# round:  23, reward:  25, experience size:  1562
# round:  24, reward:  12, experience size:  1574
# round:  25, reward:  26, experience size:  1600
# round:  26, reward:  22, experience size:  1622
# round:  27, reward:  35, experience size:  1657
# round:  28, reward:  19, experience size:  1676
# round:  29, reward:  49, experience size:  1725
# round:  30, reward:  15, experience size:  1740
# round:  31, reward:  20, experience size:  1760
# round:  32, reward:  16, experience size:  1776
# round:  33, reward:  18, experience size:  1794
# round:  34, reward:  14, experience size:  1808
# round:  35, reward:  18, experience size:  1826
# round:  36, reward:  13, experience size:  1839
# round:  37, reward:  21, experience size:  1860
# round:  38, reward:  25, experience size:  1885
# round:  39, reward:  12, experience size:  1897
# round:  40, reward:  11, experience size:  1908
# round:  41, reward:  16, experience size:  1924
# round:  42, reward:  11, experience size:  1935
# round:  43, reward:  11, experience size:  1946
# round:  44, reward:  24, experience size:  1970
# round:  45, reward:  11, experience size:  1981
# round:  46, reward:  11, experience size:  1992
# round:  47, reward:  15, experience size:  2007
# round:  48, reward:  18, experience size:  2025
# round:  49, reward:  12, experience size:  2037
# round:  50, reward:  20, experience size:  2057
# round:  51, reward:  18, experience size:  2075
# round:  52, reward:  15, experience size:  2090
# round:  53, reward:  14, experience size:  2104
# round:  54, reward:   9, experience size:  2113
# round:  55, reward:  17, experience size:  2130
# round:  56, reward:  18, experience size:  2148
# round:  57, reward:  11, experience size:  2159
# round:  58, reward:  12, experience size:  2171
# round:  59, reward:  15, experience size:  2186
# round:  60, reward:  15, experience size:  2201
# round:  61, reward:  16, experience size:  2217
# round:  62, reward:  12, experience size:  2229
# round:  63, reward:  18, experience size:  2247
# round:  64, reward:  17, experience size:  2264
# round:  65, reward:  12, experience size:  2276
# round:  66, reward:  10, experience size:  2286
# round:  67, reward:  23, experience size:  2309
# round:  68, reward:  11, experience size:  2320
# round:  69, reward:  11, experience size:  2331
# round:  70, reward:  18, experience size:  2349
# round:  71, reward:  11, experience size:  2360
# round:  72, reward:  15, experience size:  2375
# round:  73, reward:  18, experience size:  2393
# round:  74, reward:  13, experience size:  2406
# round:  75, reward:   9, experience size:  2415
# round:  76, reward:  15, experience size:  2430
# round:  77, reward:  12, experience size:  2442
# round:  78, reward:  13, experience size:  2455
# round:  79, reward:  12, experience size:  2467
# round:  80, reward:  22, experience size:  2489
# round:  81, reward:  15, experience size:  2504
# round:  82, reward:  12, experience size:  2516
# round:  83, reward:   9, experience size:  2525
# round:  84, reward:  21, experience size:  2546
# round:  85, reward:  12, experience size:  2558
# round:  86, reward:  16, experience size:  2574
# round:  87, reward:  20, experience size:  2594
# round:  88, reward:  12, experience size:  2606
# round:  89, reward:   8, experience size:  2614
# round:  90, reward:  11, experience size:  2625
# round:  91, reward:  14, experience size:  2639
# round:  92, reward:  15, experience size:  2654
# round:  93, reward:  15, experience size:  2669
# round:  94, reward:   9, experience size:  2678
# round:  95, reward:  12, experience size:  2690
# round:  96, reward:  15, experience size:  2705
# round:  97, reward:  16, experience size:  2721
# round:  98, reward:  18, experience size:  2739
# round:  99, reward:  13, experience size:  2752
# round: 100, reward:  13, experience size:  2765
# round: 101, reward:  20, experience size:  2785
# round: 102, reward:  16, experience size:  2801
# round: 103, reward:  23, experience size:  2824
# round: 104, reward:  10, experience size:  2834
# round: 105, reward:  13, experience size:  2847
# round: 106, reward:  13, experience size:  2860
# round: 107, reward:  24, experience size:  2884
# round: 108, reward:  16, experience size:  2900
# round: 109, reward:  12, experience size:  2912
# round: 110, reward:  13, experience size:  2925
# round: 111, reward:  10, experience size:  2935
# round: 112, reward:  12, experience size:  2947
# round: 113, reward:  11, experience size:  2958
# round: 114, reward:  13, experience size:  2971
# round: 115, reward:  12, experience size:  2983
# round: 116, reward:  16, experience size:  2999
# round: 117, reward:  11, experience size:  3010
# round: 118, reward:   9, experience size:  3019
# round: 119, reward:  10, experience size:  3029
# round: 120, reward:  18, experience size:  3047
# round: 121, reward:  21, experience size:  3068
# round: 122, reward:  16, experience size:  3084
# round: 123, reward:  11, experience size:  3095
# round: 124, reward:  18, experience size:  3113
# round: 125, reward:  12, experience size:  3125
# round: 126, reward:   9, experience size:  3134
# round: 127, reward:  12, experience size:  3146
# round: 128, reward:  12, experience size:  3158
# round: 129, reward:  27, experience size:  3185
# round: 130, reward:  13, experience size:  3198
# round: 131, reward:  28, experience size:  3226
# round: 132, reward:  13, experience size:  3239
# round: 133, reward:  12, experience size:  3251
# round: 134, reward:  11, experience size:  3262
# round: 135, reward:  10, experience size:  3272
# round: 136, reward:  12, experience size:  3284
# round: 137, reward:  11, experience size:  3295
# round: 138, reward:  11, experience size:  3306
# round: 139, reward:  10, experience size:  3316
# round: 140, reward:  14, experience size:  3330
# round: 141, reward:  13, experience size:  3343
# round: 142, reward:  13, experience size:  3356
# round: 143, reward:  12, experience size:  3368
# round: 144, reward:  39, experience size:  3407
# round: 145, reward:  31, experience size:  3438
# round: 146, reward:  10, experience size:  3448
# round: 147, reward:  64, experience size:  3512
# round: 148, reward: 169, experience size:  3681
# round: 149, reward:  98, experience size:  3779
# round: 150, reward:  80, experience size:  3859
# round: 151, reward:  36, experience size:  3895
# round: 152, reward:  41, experience size:  3936
# round: 153, reward:  13, experience size:  3949
# round: 154, reward:  34, experience size:  3983
# round: 155, reward:  35, experience size:  4018
# round: 156, reward:  55, experience size:  4073
# round: 157, reward:  36, experience size:  4109
# round: 158, reward:  58, experience size:  4167
# round: 159, reward:  34, experience size:  4201
# round: 160, reward:  33, experience size:  4234
# round: 161, reward:  27, experience size:  4261
# round: 162, reward:  56, experience size:  4317
# round: 163, reward:  87, experience size:  4404
# round: 164, reward:  65, experience size:  4469
# round: 165, reward:  79, experience size:  4548
# round: 166, reward:  82, experience size:  4630
# round: 167, reward:  91, experience size:  4721
# round: 168, reward:  87, experience size:  4808
# round: 169, reward: 122, experience size:  4930
# round: 170, reward:  32, experience size:  4962
# round: 171, reward:  51, experience size:  5000
# round: 172, reward:  48, experience size:  5000
# round: 173, reward:  54, experience size:  5000
# round: 174, reward:  53, experience size:  5000
# round: 175, reward: 117, experience size:  5000
# round: 176, reward:  90, experience size:  5000
# round: 177, reward:  32, experience size:  5000
# round: 178, reward:  51, experience size:  5000
# round: 179, reward:  95, experience size:  5000
# round: 180, reward:  46, experience size:  5000
# round: 181, reward:  29, experience size:  5000
# round: 182, reward: 106, experience size:  5000
# round: 183, reward:  53, experience size:  5000
# round: 184, reward:  42, experience size:  5000
# round: 185, reward:  33, experience size:  5000
# round: 186, reward:  36, experience size:  5000
# round: 187, reward:  60, experience size:  5000
# round: 188, reward:  51, experience size:  5000
# round: 189, reward:  32, experience size:  5000
# round: 190, reward:  42, experience size:  5000
# round: 191, reward:  50, experience size:  5000
# round: 192, reward:  44, experience size:  5000
# round: 193, reward:  86, experience size:  5000
# round: 194, reward:  46, experience size:  5000
# round: 195, reward:  37, experience size:  5000
# round: 196, reward:  45, experience size:  5000
# round: 197, reward:  48, experience size:  5000
# round: 198, reward:  50, experience size:  5000
# round: 199, reward:  54, experience size:  5000
# round: 200, reward:  64, experience size:  5000
# CPU times: user 3min 22s, sys: 6.04 s, total: 3min 28s
# Wall time: 3min 16s

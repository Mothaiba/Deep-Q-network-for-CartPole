# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
STEPS_PER_TARGET_MODEL_COPY = 50
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):
        self.model = tf.keras.Sequential([
            tf.keras.layers.Dense(20, activation='relu', input_shape=observation_shape),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(action_shape),
        ])
        
        self.model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.optimizers.Adam(learning_rate=lr), metrics=['accuracy'])
    
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.fit(batch_x, batch_y, verbose=0)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(mode, target_model, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = [e.observation for e in minibatch]
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(np.array(batch_curr_observations))
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = [e.new_observation for e in minibatch]
    # batch_new_qualities shape: [batch size, action size]
    batch_new_qualities = target_model.forward(np.array(batch_new_observations))
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_new_qualities[id]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*max(new_qualities)
        # target_qualities shape: [action size]
        target_qualities = curr_qualities
        target_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(target_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model.set_weights(model.get_weights())

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, target_model, minibatch)
        
        # copy the main model to the target_model
        if train_step_count >= STEPS_PER_TARGET_MODEL_COPY:
            target_model.set_weights(model.get_weights())
            train_step_count = 0
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  33, experience size:  1033
# round:   2, reward:  11, experience size:  1044
# round:   3, reward:  13, experience size:  1057
# round:   4, reward:  32, experience size:  1089
# round:   5, reward:  15, experience size:  1104
# round:   6, reward:  26, experience size:  1130
# round:   7, reward:  12, experience size:  1142
# round:   8, reward:  19, experience size:  1161
# round:   9, reward:  26, experience size:  1187
# round:  10, reward:  15, experience size:  1202
# round:  11, reward:  13, experience size:  1215
# round:  12, reward:  19, experience size:  1234
# round:  13, reward:  14, experience size:  1248
# round:  14, reward:  11, experience size:  1259
# round:  15, reward:  35, experience size:  1294
# round:  16, reward:  20, experience size:  1314
# round:  17, reward:  18, experience size:  1332
# round:  18, reward:  28, experience size:  1360
# round:  19, reward:  12, experience size:  1372
# round:  20, reward:  25, experience size:  1397
# round:  21, reward:  19, experience size:  1416
# round:  22, reward:  21, experience size:  1437
# round:  23, reward:  49, experience size:  1486
# round:  24, reward:  22, experience size:  1508
# round:  25, reward:  12, experience size:  1520
# round:  26, reward:  30, experience size:  1550
# round:  27, reward:  18, experience size:  1568
# round:  28, reward:  22, experience size:  1590
# round:  29, reward:   9, experience size:  1599
# round:  30, reward:  21, experience size:  1620
# round:  31, reward:  17, experience size:  1637
# round:  32, reward:  13, experience size:  1650
# round:  33, reward:  40, experience size:  1690
# round:  34, reward:  15, experience size:  1705
# round:  35, reward:  17, experience size:  1722
# round:  36, reward:  34, experience size:  1756
# round:  37, reward:  17, experience size:  1773
# round:  38, reward:  11, experience size:  1784
# round:  39, reward:  26, experience size:  1810
# round:  40, reward:  16, experience size:  1826
# round:  41, reward:  13, experience size:  1839
# round:  42, reward:  11, experience size:  1850
# round:  43, reward:   9, experience size:  1859
# round:  44, reward:  12, experience size:  1871
# round:  45, reward:  16, experience size:  1887
# round:  46, reward:  12, experience size:  1899
# round:  47, reward:  16, experience size:  1915
# round:  48, reward:  10, experience size:  1925
# round:  49, reward:  14, experience size:  1939
# round:  50, reward:  13, experience size:  1952
# round:  51, reward:  15, experience size:  1967
# round:  52, reward:  17, experience size:  1984
# round:  53, reward:  14, experience size:  1998
# round:  54, reward:  17, experience size:  2015
# round:  55, reward:  13, experience size:  2028
# round:  56, reward:  14, experience size:  2042
# round:  57, reward:  14, experience size:  2056
# round:  58, reward:  14, experience size:  2070
# round:  59, reward:  14, experience size:  2084
# round:  60, reward:  15, experience size:  2099
# round:  61, reward:  14, experience size:  2113
# round:  62, reward:  13, experience size:  2126
# round:  63, reward:   9, experience size:  2135
# round:  64, reward:  11, experience size:  2146
# round:  65, reward:  15, experience size:  2161
# round:  66, reward:  16, experience size:  2177
# round:  67, reward:  18, experience size:  2195
# round:  68, reward:  13, experience size:  2208
# round:  69, reward:  14, experience size:  2222
# round:  70, reward:   9, experience size:  2231
# round:  71, reward:  12, experience size:  2243
# round:  72, reward:  20, experience size:  2263
# round:  73, reward:  13, experience size:  2276
# round:  74, reward:  10, experience size:  2286
# round:  75, reward:   9, experience size:  2295
# round:  76, reward:  13, experience size:  2308
# round:  77, reward:  13, experience size:  2321
# round:  78, reward:   9, experience size:  2330
# round:  79, reward:  11, experience size:  2341
# round:  80, reward:  14, experience size:  2355
# round:  81, reward:  15, experience size:  2370
# round:  82, reward:  14, experience size:  2384
# round:  83, reward:  11, experience size:  2395
# round:  84, reward:  15, experience size:  2410
# round:  85, reward:   8, experience size:  2418
# round:  86, reward:  12, experience size:  2430
# round:  87, reward:  13, experience size:  2443
# round:  88, reward:  16, experience size:  2459
# round:  89, reward:  10, experience size:  2469
# round:  90, reward:  14, experience size:  2483
# round:  91, reward:  16, experience size:  2499
# round:  92, reward:  12, experience size:  2511
# round:  93, reward:  23, experience size:  2534
# round:  94, reward:  30, experience size:  2564
# round:  95, reward:  16, experience size:  2580
# round:  96, reward:  18, experience size:  2598
# round:  97, reward:  13, experience size:  2611
# round:  98, reward:  13, experience size:  2624
# round:  99, reward:  14, experience size:  2638
# round: 100, reward:  19, experience size:  2657
# round: 101, reward:  18, experience size:  2675
# round: 102, reward:  25, experience size:  2700
# round: 103, reward:  12, experience size:  2712
# round: 104, reward:  23, experience size:  2735
# round: 105, reward:  12, experience size:  2747
# round: 106, reward:  17, experience size:  2764
# round: 107, reward:  13, experience size:  2777
# round: 108, reward:   8, experience size:  2785
# round: 109, reward:  13, experience size:  2798
# round: 110, reward:  17, experience size:  2815
# round: 111, reward:  14, experience size:  2829
# round: 112, reward:  10, experience size:  2839
# round: 113, reward:  18, experience size:  2857
# round: 114, reward:  22, experience size:  2879
# round: 115, reward:  10, experience size:  2889
# round: 116, reward:  31, experience size:  2920
# round: 117, reward:  11, experience size:  2931
# round: 118, reward:  10, experience size:  2941
# round: 119, reward:  12, experience size:  2953
# round: 120, reward:  19, experience size:  2972
# round: 121, reward:  40, experience size:  3012
# round: 122, reward:  17, experience size:  3029
# round: 123, reward:  35, experience size:  3064
# round: 124, reward:  19, experience size:  3083
# round: 125, reward:  14, experience size:  3097
# round: 126, reward:  47, experience size:  3144
# round: 127, reward:  15, experience size:  3159
# round: 128, reward:   9, experience size:  3168
# round: 129, reward:  10, experience size:  3178
# round: 130, reward:  12, experience size:  3190
# round: 131, reward:  20, experience size:  3210
# round: 132, reward:  10, experience size:  3220
# round: 133, reward:  14, experience size:  3234
# round: 134, reward:  11, experience size:  3245
# round: 135, reward:  31, experience size:  3276
# round: 136, reward:  67, experience size:  3343
# round: 137, reward:  15, experience size:  3358
# round: 138, reward:  12, experience size:  3370
# round: 139, reward:  10, experience size:  3380
# round: 140, reward:  12, experience size:  3392
# round: 141, reward:   8, experience size:  3400
# round: 142, reward:  10, experience size:  3410
# round: 143, reward:  29, experience size:  3439
# round: 144, reward:  78, experience size:  3517
# round: 145, reward:  27, experience size:  3544
# round: 146, reward: 130, experience size:  3674
# round: 147, reward:  36, experience size:  3710
# round: 148, reward:  42, experience size:  3752
# round: 149, reward:  90, experience size:  3842
# round: 150, reward:  62, experience size:  3904
# round: 151, reward:  70, experience size:  3974
# round: 152, reward:  64, experience size:  4038
# round: 153, reward:  79, experience size:  4117
# round: 154, reward:  76, experience size:  4193
# round: 155, reward:  65, experience size:  4258
# round: 156, reward:  97, experience size:  4355
# round: 157, reward:  63, experience size:  4418
# round: 158, reward:  34, experience size:  4452
# round: 159, reward:  74, experience size:  4526
# round: 160, reward:  80, experience size:  4606
# round: 161, reward:  76, experience size:  4682
# round: 162, reward:  98, experience size:  4780
# round: 163, reward:  60, experience size:  4840
# round: 164, reward:  63, experience size:  4903
# round: 165, reward:  85, experience size:  4988
# round: 166, reward: 132, experience size:  5000
# round: 167, reward:  76, experience size:  5000
# round: 168, reward:  50, experience size:  5000
# round: 169, reward:  80, experience size:  5000
# round: 170, reward:  47, experience size:  5000
# round: 171, reward:  34, experience size:  5000
# round: 172, reward:  36, experience size:  5000
# round: 173, reward:  98, experience size:  5000
# round: 174, reward:  58, experience size:  5000
# round: 175, reward:  36, experience size:  5000
# round: 176, reward:  44, experience size:  5000
# round: 177, reward:  85, experience size:  5000
# round: 178, reward: 102, experience size:  5000
# round: 179, reward:  86, experience size:  5000
# round: 180, reward: 116, experience size:  5000
# round: 181, reward:  79, experience size:  5000
# round: 182, reward:  79, experience size:  5000
# round: 183, reward:  81, experience size:  5000
# round: 184, reward:  70, experience size:  5000
# round: 185, reward:  69, experience size:  5000
# round: 186, reward: 183, experience size:  5000
# round: 187, reward: 121, experience size:  5000
# round: 188, reward: 110, experience size:  5000
# round: 189, reward: 119, experience size:  5000
# round: 190, reward:  55, experience size:  5000
# round: 191, reward:  61, experience size:  5000
# round: 192, reward: 100, experience size:  5000
# round: 193, reward:  81, experience size:  5000
# round: 194, reward:  54, experience size:  5000
# round: 195, reward:  58, experience size:  5000
# round: 196, reward:  55, experience size:  5000
# round: 197, reward: 175, experience size:  5000
# round: 198, reward: 101, experience size:  5000
# round: 199, reward:  48, experience size:  5000
# round: 200, reward:  51, experience size:  5000
# CPU times: user 5min 19s, sys: 8.35 s, total: 5min 27s
# Wall time: 5min 12s

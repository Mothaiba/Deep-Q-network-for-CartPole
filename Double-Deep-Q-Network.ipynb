# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
STEPS_PER_TARGET_MODEL_COPY = 50
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):
        self.model = tf.keras.Sequential([
            tf.keras.layers.Dense(20, activation='relu', input_shape=observation_shape),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(action_shape),
        ])
        
        self.model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.optimizers.Adam(learning_rate=lr), metrics=['accuracy'])
    
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.train_on_batch(batch_x, batch_y)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(mode, target_model, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = np.array([e.observation for e in minibatch])
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(batch_curr_observations)
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = np.array([e.new_observation for e in minibatch])
    # batch_q_new_qualities shape: [batch size, action size]
    # qualities of the actions on new observations as evaluated by the main network
    batch_q_new_qualities = model.forward(batch_new_observations)
    # batch_best_actions shape: [batch size]
    # best action for each state as evaluated by the main network
    batch_best_actions = tf.argmax(batch_q_new_qualities, axis=1)
    # batch_t_new_qualities shape: [batch size, action size]
    # qualities of the actions on new observations as evaluated by the target network
    batch_t_new_qualities = target_model.forward(batch_new_observations)
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_t_new_qualities[id]
        selected_quality : float = new_qualities[batch_best_actions[id]]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*selected_quality
        # desired_qualities shape: [action size]
        desired_qualities = curr_qualities
        desired_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(desired_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model.set_weights(model.get_weights())

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, target_model, minibatch)
        
        # copy the main model to the target_model
        if train_step_count >= STEPS_PER_TARGET_MODEL_COPY:
            target_model.set_weights(model.get_weights())
            train_step_count = 0
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  38, experience size:  1038
# round:   2, reward:  20, experience size:  1058
# round:   3, reward:  66, experience size:  1124
# round:   4, reward:  18, experience size:  1142
# round:   5, reward:  23, experience size:  1165
# round:   6, reward:  13, experience size:  1178
# round:   7, reward:  16, experience size:  1194
# round:   8, reward:  14, experience size:  1208
# round:   9, reward:  23, experience size:  1231
# round:  10, reward:  20, experience size:  1251
# round:  11, reward:  26, experience size:  1277
# round:  12, reward:  16, experience size:  1293
# round:  13, reward:  18, experience size:  1311
# round:  14, reward:  14, experience size:  1325
# round:  15, reward:  14, experience size:  1339
# round:  16, reward:  14, experience size:  1353
# round:  17, reward:  16, experience size:  1369
# round:  18, reward:  24, experience size:  1393
# round:  19, reward:  23, experience size:  1416
# round:  20, reward:  24, experience size:  1440
# round:  21, reward:  17, experience size:  1457
# round:  22, reward:  17, experience size:  1474
# round:  23, reward:  26, experience size:  1500
# round:  24, reward:  49, experience size:  1549
# round:  25, reward:  25, experience size:  1574
# round:  26, reward:  20, experience size:  1594
# round:  27, reward:  49, experience size:  1643
# round:  28, reward:  11, experience size:  1654
# round:  29, reward:  24, experience size:  1678
# round:  30, reward:  10, experience size:  1688
# round:  31, reward:  20, experience size:  1708
# round:  32, reward:  10, experience size:  1718
# round:  33, reward:   9, experience size:  1727
# round:  34, reward:  17, experience size:  1744
# round:  35, reward:  25, experience size:  1769
# round:  36, reward:  14, experience size:  1783
# round:  37, reward:  29, experience size:  1812
# round:  38, reward:  13, experience size:  1825
# round:  39, reward:  11, experience size:  1836
# round:  40, reward:  14, experience size:  1850
# round:  41, reward:  27, experience size:  1877
# round:  42, reward:  13, experience size:  1890
# round:  43, reward:   9, experience size:  1899
# round:  44, reward:  11, experience size:  1910
# round:  45, reward:  20, experience size:  1930
# round:  46, reward:  20, experience size:  1950
# round:  47, reward:  16, experience size:  1966
# round:  48, reward:  21, experience size:  1987
# round:  49, reward:  15, experience size:  2002
# round:  50, reward:  54, experience size:  2056
# round:  51, reward:  13, experience size:  2069
# round:  52, reward:  36, experience size:  2105
# round:  53, reward:  15, experience size:  2120
# round:  54, reward:  16, experience size:  2136
# round:  55, reward:  17, experience size:  2153
# round:  56, reward:  10, experience size:  2163
# round:  57, reward:  15, experience size:  2178
# round:  58, reward:  16, experience size:  2194
# round:  59, reward:  24, experience size:  2218
# round:  60, reward:  11, experience size:  2229
# round:  61, reward:  16, experience size:  2245
# round:  62, reward:  14, experience size:  2259
# round:  63, reward:  10, experience size:  2269
# round:  64, reward:  10, experience size:  2279
# round:  65, reward:  17, experience size:  2296
# round:  66, reward:   8, experience size:  2304
# round:  67, reward:  13, experience size:  2317
# round:  68, reward:  14, experience size:  2331
# round:  69, reward:  21, experience size:  2352
# round:  70, reward:  14, experience size:  2366
# round:  71, reward:  14, experience size:  2380
# round:  72, reward:  13, experience size:  2393
# round:  73, reward:  17, experience size:  2410
# round:  74, reward:  39, experience size:  2449
# round:  75, reward:  13, experience size:  2462
# round:  76, reward:  15, experience size:  2477
# round:  77, reward:  15, experience size:  2492
# round:  78, reward:  12, experience size:  2504
# round:  79, reward:  22, experience size:  2526
# round:  80, reward:  18, experience size:  2544
# round:  81, reward:  15, experience size:  2559
# round:  82, reward:  11, experience size:  2570
# round:  83, reward:  13, experience size:  2583
# round:  84, reward:  14, experience size:  2597
# round:  85, reward:  11, experience size:  2608
# round:  86, reward:  15, experience size:  2623
# round:  87, reward:  21, experience size:  2644
# round:  88, reward:  15, experience size:  2659
# round:  89, reward:  10, experience size:  2669
# round:  90, reward:  19, experience size:  2688
# round:  91, reward:  54, experience size:  2742
# round:  92, reward:  10, experience size:  2752
# round:  93, reward:  10, experience size:  2762
# round:  94, reward:  52, experience size:  2814
# round:  95, reward:  16, experience size:  2830
# round:  96, reward:  19, experience size:  2849
# round:  97, reward:  20, experience size:  2869
# round:  98, reward:  16, experience size:  2885
# round:  99, reward:   8, experience size:  2893
# round: 100, reward:  12, experience size:  2905
# round: 101, reward:   9, experience size:  2914
# round: 102, reward:   9, experience size:  2923
# round: 103, reward:  10, experience size:  2933
# round: 104, reward:  17, experience size:  2950
# round: 105, reward:  33, experience size:  2983
# round: 106, reward:  12, experience size:  2995
# round: 107, reward:   9, experience size:  3004
# round: 108, reward:  18, experience size:  3022
# round: 109, reward:  13, experience size:  3035
# round: 110, reward:  11, experience size:  3046
# round: 111, reward:  10, experience size:  3056
# round: 112, reward:   9, experience size:  3065
# round: 113, reward:   9, experience size:  3074
# round: 114, reward:  12, experience size:  3086
# round: 115, reward:  36, experience size:  3122
# round: 116, reward:  45, experience size:  3167
# round: 117, reward: 221, experience size:  3388
# round: 118, reward: 162, experience size:  3550
# round: 119, reward:  41, experience size:  3591
# round: 120, reward: 103, experience size:  3694
# round: 121, reward:  50, experience size:  3744
# round: 122, reward:  80, experience size:  3824
# round: 123, reward:  53, experience size:  3877
# round: 124, reward:  45, experience size:  3922
# round: 125, reward:  89, experience size:  4011
# round: 126, reward:  43, experience size:  4054
# round: 127, reward:  51, experience size:  4105
# round: 128, reward:  45, experience size:  4150
# round: 129, reward:  36, experience size:  4186
# round: 130, reward:  47, experience size:  4233
# round: 131, reward:  94, experience size:  4327
# round: 132, reward:  42, experience size:  4369
# round: 133, reward:  92, experience size:  4461
# round: 134, reward:  77, experience size:  4538
# round: 135, reward:  76, experience size:  4614
# round: 136, reward: 138, experience size:  4752
# round: 137, reward:  73, experience size:  4825
# round: 138, reward:  73, experience size:  4898
# round: 139, reward:  46, experience size:  4944
# round: 140, reward:  48, experience size:  4992
# round: 141, reward:  47, experience size:  5000
# round: 142, reward:  46, experience size:  5000
# round: 143, reward:  77, experience size:  5000
# round: 144, reward:  21, experience size:  5000
# round: 145, reward:  94, experience size:  5000
# round: 146, reward:  45, experience size:  5000
# round: 147, reward:  31, experience size:  5000
# round: 148, reward:  42, experience size:  5000
# round: 149, reward:  67, experience size:  5000
# round: 150, reward:  42, experience size:  5000
# round: 151, reward:  73, experience size:  5000
# round: 152, reward:  48, experience size:  5000
# round: 153, reward:  47, experience size:  5000
# round: 154, reward:  35, experience size:  5000
# round: 155, reward:  73, experience size:  5000
# round: 156, reward:  40, experience size:  5000
# round: 157, reward: 112, experience size:  5000
# round: 158, reward: 105, experience size:  5000
# round: 159, reward:  65, experience size:  5000
# round: 160, reward:  49, experience size:  5000
# round: 161, reward:  85, experience size:  5000
# round: 162, reward: 103, experience size:  5000
# round: 163, reward:  25, experience size:  5000
# round: 164, reward:  70, experience size:  5000
# round: 165, reward:  33, experience size:  5000
# round: 166, reward: 102, experience size:  5000
# round: 167, reward:  78, experience size:  5000
# round: 168, reward:  40, experience size:  5000
# round: 169, reward:  30, experience size:  5000
# round: 170, reward:  44, experience size:  5000
# round: 171, reward:  96, experience size:  5000
# round: 172, reward:  65, experience size:  5000
# round: 173, reward:  60, experience size:  5000
# round: 174, reward:  49, experience size:  5000
# round: 175, reward:  43, experience size:  5000
# round: 176, reward:  87, experience size:  5000
# round: 177, reward:  45, experience size:  5000
# round: 178, reward:  49, experience size:  5000
# round: 179, reward:  64, experience size:  5000
# round: 180, reward:  89, experience size:  5000
# round: 181, reward:  60, experience size:  5000
# round: 182, reward: 125, experience size:  5000
# round: 183, reward: 114, experience size:  5000
# round: 184, reward: 162, experience size:  5000
# round: 185, reward: 142, experience size:  5000
# round: 186, reward: 100, experience size:  5000
# round: 187, reward: 185, experience size:  5000
# round: 188, reward: 102, experience size:  5000
# round: 189, reward:  87, experience size:  5000
# round: 190, reward:  86, experience size:  5000
# round: 191, reward:  89, experience size:  5000
# round: 192, reward: 249, experience size:  5000
# round: 193, reward: 160, experience size:  5000
# round: 194, reward: 230, experience size:  5000
# round: 195, reward: 174, experience size:  5000
# round: 196, reward: 167, experience size:  5000
# round: 197, reward: 161, experience size:  5000
# round: 198, reward: 273, experience size:  5000
# round: 199, reward: 240, experience size:  5000
# round: 200, reward: 199, experience size:  5000
# CPU times: user 7min 28s, sys: 12.5 s, total: 7min 41s
# Wall time: 7min 14s

# %% [markdown]
# # Importation and setup

# %%
from collections import deque, namedtuple
import random

import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

env = gym.make('CartPole-v1')
env.seed(SEED)
# Out:
# [42]

# %% [markdown]
# # CartPole environment description

# %%
print('Action space:', env.action_space)
print('Observation (or state) space:', env.observation_space)
# Out:
# Action space: Discrete(2)
# Observation (or state) space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# According to [OpenAI gym wiki](https://github.com/openai/gym/wiki/CartPole-v0):
#
# There are 2 actions we can take:
# - Move to the left (denoted as `0`).
# - Move to the right (denoted as `1`).
#
# An observation contains a list of 4 floating-point numbers, they are, respectively:
# - Cart position.
# - Cart velocity.
# - Pole angle.
# - Pole velocity at tip.
#
# Common APIs of the game:
# - env.seed(seed: int) -> None. Set random seed.
# - env.reset() -> None. Reset the game, used when we get a game-over.
# - env.action_space.sample() -> int (an action id). Get a random valid action.
# - env.step(action: int) -> None. Simulate this action.

# %% [markdown]
# # Hyper-parameters

# %%
GAMMA = 0.8 # the discount factor of future reward
TARGET_LEARNING_RATE = 0.01

MIN_MEMORY_SIZE = 1000
MAX_MEMORY_SIZE = 5000
STEPS_PER_TARGET_MODEL_COPY = 50
SIMULATIONS_PER_TRAINING = 4 # at each step, we simulate this number of experiences before training a minibatch

BATCH_SIZE = 32
LEARNING_RATE = 0.001
TRAIN_ROUNDS = 200 # a round means a game

# higher epsilon means more exploration.
# epsilon is decreased gradually.
def get_epsilon(curr_round: int, train_rounds: int):
    return 1 - curr_round/train_rounds

# %% [markdown]
# # Class and function definitions

# %%
Experience = namedtuple('Experience', 'observation action reward new_observation done')

# Experience Replay
class ExperienceMemory():
    def __init__(self, memory_capacity):
        self.memory = deque(maxlen=memory_capacity)
    
    def __len__(self):
        return len(self.memory)
    
    def push(self, e: Experience):
        self.memory.append(e)
    
    def sample(self, size):
        return random.sample(self.memory, size)

# %%
class Model():
    def __init__(self, observation_shape, action_shape, lr):
        inputs = layers.Input(shape=(observation_shape))
        h1 = layers.Dense(20, activation='relu')(inputs)
        h1 = layers.Dense(10, activation='relu')(h1)
        V = layers.Dense(1)(h1)
        
        h2 = layers.Dense(20, activation='relu')(inputs)
        h2 = layers.Dense(10, activation='relu')(h2)
        advantage = layers.Dense(action_shape)(h2)
        mean_adv = layers.Lambda(lambda x: tf.keras.backend.mean(x, axis=1))(advantage)
        
        outputs = layers.Add()([V, layers.Subtract()([advantage, mean_adv])])
    
        self.model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
        
        self.model.compile(
            loss=tf.keras.losses.Huber(), 
            optimizer=tf.optimizers.Adam(learning_rate=lr), 
            metrics=['accuracy']
        )
    
    def set_weights(self, weights):
        self.model.set_weights(weights)
    
    def get_weights(self):
        return self.model.get_weights()
    
    def forward(self, batch_observations):
        return self.model.predict(batch_observations)
            
    def train(self, batch_x, batch_y):
        self.model.train_on_batch(batch_x, batch_y)

# %%
def simulate_experience(env, model, eps, curr_observation):
    # select the next action (from the current state)
    if random.random() < eps:
        # use a random state
        action = env.action_space.sample()
    else:
        # use the best action (according to the current model)
        action_scores = model.forward(np.expand_dims(curr_observation, 0)).flatten()
        action = np.argmax(action_scores)

    # simulate this action and push the experience to experience_memory
    new_observation, reward, done, info = env.step(action)
    env.render()
    return Experience(curr_observation, action, reward, new_observation, done)

# %%
def train(model, target_model, minibatch):
    # batch_curr_observations shape: [batch size, observation shape]
    batch_curr_observations = np.array([e.observation for e in minibatch])
    # batch_curr_qualities shape: [batch size, action size]
    batch_curr_qualities = model.forward(batch_curr_observations)
    
    # batch_new_observations shape: [batch size, observation shape]
    batch_new_observations = np.array([e.new_observation for e in minibatch])
    # batch_q_new_qualities shape: [batch size, action size]
    # qualities of the actions on new observations as evaluated by the main network
    batch_q_new_qualities = model.forward(batch_new_observations)
    # batch_best_actions shape: [batch size]
    # best action for each state as evaluated by the main network
    batch_best_actions = tf.argmax(batch_q_new_qualities, axis=1)
    # batch_t_new_qualities shape: [batch size, action size]
    # qualities of the actions on new observations as evaluated by the target network
    batch_t_new_qualities = target_model.forward(batch_new_observations)
    
    batch_x, batch_y = [], []
    for id, e in enumerate(minibatch):
        observation = e.observation
        action = e.action
        reward = e.reward
        new_observation = e.new_observation
        done = e.done
        
        # curr_qualities shape: [action size]
        curr_qualities = batch_curr_qualities[id]
        # new_qualities shape: [action size]
        new_qualities = batch_t_new_qualities[id]
        selected_quality : float = new_qualities[batch_best_actions[id]]
        if done:
            updated_quality : float = reward
        else:
            updated_quality : float = reward + GAMMA*selected_quality
        # desired_qualities shape: [action size]
        desired_qualities = curr_qualities
        desired_qualities[action] = (1 - TARGET_LEARNING_RATE)*curr_qualities[action] + TARGET_LEARNING_RATE*updated_quality
        
        batch_x.append(observation)
        batch_y.append(desired_qualities)
    
    model.train(np.array(batch_x), np.array(batch_y))

# %% [markdown]
# # Model training

# %%
experience_memory = ExperienceMemory(memory_capacity=MAX_MEMORY_SIZE)

model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model = Model(observation_shape=env.observation_space.shape, action_shape=env.action_space.n, lr=LEARNING_RATE)
target_model.set_weights(model.get_weights())

# %%
# %%time

train_step_count = 0
eps = 1
done = True

# Filled the experience_memory with minimum number of experiences.
while len(experience_memory) < MIN_MEMORY_SIZE:
    if done:
        observation = env.reset()
        done = False
    
    e = simulate_experience(env, model, eps, observation)
    experience_memory.push(e)
    
    observation = e.new_observation
    done = e.done

# train the deep-q-model
for curr_round in range(1, TRAIN_ROUNDS + 1):
    observation = env.reset()
    eps = get_epsilon(curr_round, TRAIN_ROUNDS)
    cumulative_reward = 0
    done = False
    
    while not done:
        # simulation to get new experiences
        for sim_id in range(SIMULATIONS_PER_TRAINING):
            e = simulate_experience(env, model, eps, observation)
            experience_memory.push(e)
            
            observation = e.new_observation
            cumulative_reward += e.reward
            done = e.done
            
            if done:
                break
        
        # train the main model
        if len(experience_memory) >= MIN_MEMORY_SIZE:
            train_step_count += 1
            minibatch = experience_memory.sample(BATCH_SIZE)
            train(model, target_model, minibatch)
        
        # copy the main model to the target_model
        if train_step_count >= STEPS_PER_TARGET_MODEL_COPY:
            target_model.set_weights(model.get_weights())
            train_step_count = 0
        
    print(f'round: {curr_round:3}, reward: {int(cumulative_reward):3}, experience size: {len(experience_memory):5}')

env.close()
# Out:
# round:   1, reward:  14, experience size:  1014
# round:   2, reward:  11, experience size:  1025
# round:   3, reward:  11, experience size:  1036
# round:   4, reward:  33, experience size:  1069
# round:   5, reward:   9, experience size:  1078
# round:   6, reward:  27, experience size:  1105
# round:   7, reward:  10, experience size:  1115
# round:   8, reward:  14, experience size:  1129
# round:   9, reward:  23, experience size:  1152
# round:  10, reward:  23, experience size:  1175
# round:  11, reward:  33, experience size:  1208
# round:  12, reward:  33, experience size:  1241
# round:  13, reward:  33, experience size:  1274
# round:  14, reward:  25, experience size:  1299
# round:  15, reward:  16, experience size:  1315
# round:  16, reward:  14, experience size:  1329
# round:  17, reward:  34, experience size:  1363
# round:  18, reward:  23, experience size:  1386
# round:  19, reward:  20, experience size:  1406
# round:  20, reward:  15, experience size:  1421
# round:  21, reward:  12, experience size:  1433
# round:  22, reward:  12, experience size:  1445
# round:  23, reward:  53, experience size:  1498
# round:  24, reward:  17, experience size:  1515
# round:  25, reward:  26, experience size:  1541
# round:  26, reward:  11, experience size:  1552
# round:  27, reward:  16, experience size:  1568
# round:  28, reward:  36, experience size:  1604
# round:  29, reward:  24, experience size:  1628
# round:  30, reward:  17, experience size:  1645
# round:  31, reward:  28, experience size:  1673
# round:  32, reward:  12, experience size:  1685
# round:  33, reward:   9, experience size:  1694
# round:  34, reward:  12, experience size:  1706
# round:  35, reward:  12, experience size:  1718
# round:  36, reward:   9, experience size:  1727
# round:  37, reward:  15, experience size:  1742
# round:  38, reward:  13, experience size:  1755
# round:  39, reward:  10, experience size:  1765
# round:  40, reward:  14, experience size:  1779
# round:  41, reward:  17, experience size:  1796
# round:  42, reward:  10, experience size:  1806
# round:  43, reward:  47, experience size:  1853
# round:  44, reward:  20, experience size:  1873
# round:  45, reward:  13, experience size:  1886
# round:  46, reward:  16, experience size:  1902
# round:  47, reward:  12, experience size:  1914
# round:  48, reward:  27, experience size:  1941
# round:  49, reward:  14, experience size:  1955
# round:  50, reward:  17, experience size:  1972
# round:  51, reward:   9, experience size:  1981
# round:  52, reward:  48, experience size:  2029
# round:  53, reward:  13, experience size:  2042
# round:  54, reward:  10, experience size:  2052
# round:  55, reward:  10, experience size:  2062
# round:  56, reward:  12, experience size:  2074
# round:  57, reward:  15, experience size:  2089
# round:  58, reward:  11, experience size:  2100
# round:  59, reward:  10, experience size:  2110
# round:  60, reward:  13, experience size:  2123
# round:  61, reward:  12, experience size:  2135
# round:  62, reward:  11, experience size:  2146
# round:  63, reward:  35, experience size:  2181
# round:  64, reward:  13, experience size:  2194
# round:  65, reward:  17, experience size:  2211
# round:  66, reward:  10, experience size:  2221
# round:  67, reward:  16, experience size:  2237
# round:  68, reward:  13, experience size:  2250
# round:  69, reward:  24, experience size:  2274
# round:  70, reward:  10, experience size:  2284
# round:  71, reward:  18, experience size:  2302
# round:  72, reward:  11, experience size:  2313
# round:  73, reward:  16, experience size:  2329
# round:  74, reward:  19, experience size:  2348
# round:  75, reward:   9, experience size:  2357
# round:  76, reward:  20, experience size:  2377
# round:  77, reward:  23, experience size:  2400
# round:  78, reward:  17, experience size:  2417
# round:  79, reward:  13, experience size:  2430
# round:  80, reward:  13, experience size:  2443
# round:  81, reward:  12, experience size:  2455
# round:  82, reward:   9, experience size:  2464
# round:  83, reward:  11, experience size:  2475
# round:  84, reward:   8, experience size:  2483
# round:  85, reward:  11, experience size:  2494
# round:  86, reward:  11, experience size:  2505
# round:  87, reward:   9, experience size:  2514
# round:  88, reward:  10, experience size:  2524
# round:  89, reward:   9, experience size:  2533
# round:  90, reward:  14, experience size:  2547
# round:  91, reward:  14, experience size:  2561
# round:  92, reward:  15, experience size:  2576
# round:  93, reward:   9, experience size:  2585
# round:  94, reward:   8, experience size:  2593
# round:  95, reward:  19, experience size:  2612
# round:  96, reward:  13, experience size:  2625
# round:  97, reward:  14, experience size:  2639
# round:  98, reward:  12, experience size:  2651
# round:  99, reward:  11, experience size:  2662
# round: 100, reward:  22, experience size:  2684
# round: 101, reward:  14, experience size:  2698
# round: 102, reward:  17, experience size:  2715
# round: 103, reward:  17, experience size:  2732
# round: 104, reward:  26, experience size:  2758
# round: 105, reward:  12, experience size:  2770
# round: 106, reward:  18, experience size:  2788
# round: 107, reward:  23, experience size:  2811
# round: 108, reward:  18, experience size:  2829
# round: 109, reward:  23, experience size:  2852
# round: 110, reward:  14, experience size:  2866
# round: 111, reward:  28, experience size:  2894
# round: 112, reward:  12, experience size:  2906
# round: 113, reward:  21, experience size:  2927
# round: 114, reward:  15, experience size:  2942
# round: 115, reward:  11, experience size:  2953
# round: 116, reward:  17, experience size:  2970
# round: 117, reward:  28, experience size:  2998
# round: 118, reward:  20, experience size:  3018
# round: 119, reward:  21, experience size:  3039
# round: 120, reward:  21, experience size:  3060
# round: 121, reward:  34, experience size:  3094
# round: 122, reward:  15, experience size:  3109
# round: 123, reward:  51, experience size:  3160
# round: 124, reward:  44, experience size:  3204
# round: 125, reward:  35, experience size:  3239
# round: 126, reward:  38, experience size:  3277
# round: 127, reward:  35, experience size:  3312
# round: 128, reward:  25, experience size:  3337
# round: 129, reward:  43, experience size:  3380
# round: 130, reward:  71, experience size:  3451
# round: 131, reward:  45, experience size:  3496
# round: 132, reward:  45, experience size:  3541
# round: 133, reward:  37, experience size:  3578
# round: 134, reward:  58, experience size:  3636
# round: 135, reward:  39, experience size:  3675
# round: 136, reward:  58, experience size:  3733
# round: 137, reward:  67, experience size:  3800
# round: 138, reward:  63, experience size:  3863
# round: 139, reward:  33, experience size:  3896
# round: 140, reward:  25, experience size:  3921
# round: 141, reward:  37, experience size:  3958
# round: 142, reward:  64, experience size:  4022
# round: 143, reward:  52, experience size:  4074
# round: 144, reward:  96, experience size:  4170
# round: 145, reward:  50, experience size:  4220
# round: 146, reward:  35, experience size:  4255
# round: 147, reward: 117, experience size:  4372
# round: 148, reward: 104, experience size:  4476
# round: 149, reward:  47, experience size:  4523
# round: 150, reward:  52, experience size:  4575
# round: 151, reward:  42, experience size:  4617
# round: 152, reward:  40, experience size:  4657
# round: 153, reward:  77, experience size:  4734
# round: 154, reward:  46, experience size:  4780
# round: 155, reward:  77, experience size:  4857
# round: 156, reward:  35, experience size:  4892
# round: 157, reward:  60, experience size:  4952
# round: 158, reward: 107, experience size:  5000
# round: 159, reward:  67, experience size:  5000
# round: 160, reward:  68, experience size:  5000
# round: 161, reward: 191, experience size:  5000
# round: 162, reward: 116, experience size:  5000
# round: 163, reward: 121, experience size:  5000
# round: 164, reward: 146, experience size:  5000
# round: 165, reward: 132, experience size:  5000
# round: 166, reward: 162, experience size:  5000
# round: 167, reward: 199, experience size:  5000
# round: 168, reward: 219, experience size:  5000
# round: 169, reward:  59, experience size:  5000
# round: 170, reward:  54, experience size:  5000
# round: 171, reward: 207, experience size:  5000
# round: 172, reward: 259, experience size:  5000
# round: 173, reward: 209, experience size:  5000
# round: 174, reward: 419, experience size:  5000
# round: 175, reward: 270, experience size:  5000
# round: 176, reward: 176, experience size:  5000
# round: 177, reward: 218, experience size:  5000
# round: 178, reward: 259, experience size:  5000
# round: 179, reward: 328, experience size:  5000
# round: 180, reward: 265, experience size:  5000
# round: 181, reward: 177, experience size:  5000
# round: 182, reward: 314, experience size:  5000
# round: 183, reward: 181, experience size:  5000
# round: 184, reward: 317, experience size:  5000
# round: 185, reward: 253, experience size:  5000
# round: 186, reward: 213, experience size:  5000
# round: 187, reward: 238, experience size:  5000
# round: 188, reward: 225, experience size:  5000
# round: 189, reward: 261, experience size:  5000
# round: 190, reward: 245, experience size:  5000
# round: 191, reward: 203, experience size:  5000
# round: 192, reward: 242, experience size:  5000
# round: 193, reward: 210, experience size:  5000
# round: 194, reward: 211, experience size:  5000
# round: 195, reward: 251, experience size:  5000
# round: 196, reward: 209, experience size:  5000
# round: 197, reward: 251, experience size:  5000
# round: 198, reward: 197, experience size:  5000
# round: 199, reward: 182, experience size:  5000
# round: 200, reward: 250, experience size:  5000
# CPU times: user 11min 3s, sys: 17.6 s, total: 11min 21s
# Wall time: 10min 46s
